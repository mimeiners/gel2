# %% [markdown]
# # Einstieg in LTspice
#
# Sie benötigen eine Bibliothek aus dem Python-Paket-Archiv, um mit LTSpice interagieren zu können. Entnehmen Sie die
# notwendigen Installationsschritte bitte der entsprechenden Webseite [PyLTSpice](https://github.com/nunobrum/PyLTSpice).
#
# ## Laden der notwendigen Bibliotheken

# %%
from PyLTSpice import RawRead
import matplotlib.pyplot as plt

# %% [markdown]
# ## Einlesen der Rohdaten

# %%
ltr = RawRead('../files/spice/bsp433_reisch.raw')
# print(ltr.get_trace_names())
# print(ltr.get_raw_property())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ltr = RawRead('../files/spice/bsp433_reisch.raw')
#       2 # print(ltr.get_trace_names())
#       3 # print(ltr.get_raw_property())
#
# File ~/Library/Python/3.13/lib/python/site-packages/spicelib/raw/raw_read.py:305, in RawRead.__init__(self, raw_filename, traces_to_read, dialect, verbose)
#     303 plot_nr = 1
#     304 # read the contents of the file, one plot at a time
# --> 305 with open(raw_filename, "rb") as raw_file:
#     306     while get_remaining_bytes(raw_file) > MIN_BYTES_IN_FILE:
#     307         plot = PlotData(raw_file, raw_filename, plot_nr, self.encoding, self._dialect, verbose)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../files/spice/bsp433_reisch.raw'

# %% [markdown]
# ## Zuweisen der Daten zu Variablen

# %%
t = ltr.get_trace('time')
V1 = ltr.get_trace('V(1)')
V2 = ltr.get_trace('V(2)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 t = ltr.get_trace('time')
#       2 V1 = ltr.get_trace('V(1)')
#       3 V2 = ltr.get_trace('V(2)')
#
# NameError: name 'ltr' is not defined

# %% [markdown]
# ## Plotten der Spannungsverläufe

# %%
plt.plot(t, V1, label="$v_1(t)$")
plt.plot(t, V2, label="$v_2(t)$")
plt.legend()
plt.grid()
plt.xlabel('Zeit t in s')
plt.ylabel('Spannung V in V')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(t, V1, label="$v_1(t)$")
#       2 plt.plot(t, V2, label="$v_2(t)$")
#       3 plt.legend()
#
# NameError: name 't' is not defined
